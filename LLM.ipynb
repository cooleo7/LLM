# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My\ Drive/LLM
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/LLM

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 28.4 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Answer in {context} about {question}. Inquire about the ideal residential areas within London. Consider various factors such as amenities, ambiance, accessibility, and community vibe. Provide insights into neighborhoods that are commonly regarded as desirable and outline their unique features and attractions. Aim to offer a comprehensive overview to assist individuals seeking guidance on selecting an optimal location to reside in the city.

# %%
# !python LLM_QA.py
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# comment: Waterloo is definitely a good area to live in, especially for a short-term stay. Its central location, access to public transportation, and proximity to popular landmarks make it a desirable place to live. Just be prepared for the crowds and higher prices, but overall, it's a great choice for a temporary residence.

# %% [markdown]
# # Summarise in {context} about {question}. Summerise a specific neighborhood in London that you believe is the best place to live.Highlight the unique features and attractions of this neighborhood.Discuss the amenities and facilities available, such as parks, schools, shopping centers, and transportation options. Share personal experiences or anecdotes that showcase why this neighborhood stands out as the ideal living location.

# %%
# !python LLM_QA.py
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some comments suggest that the Waterloo area is a good place to live, especially for a short stay. It is centrally located, has easy access to public transport, and is close to many attractions in London. However, the area can be expensive, crowded with tourists and commuters, and lacking in varied options for bars and supermarkets. Overall, it seems to be a convenient and lively place to live, especially for a temporary stay.

# %% [markdown]
# # Refer in {context} about {question} in terms of the cost of rent, public transportation station, how many supermarkets near to this neighbourhood, how safe this area. If the question is focused on some specific features, then answer focusing on the features.

# %%
# !python LLM_QA.py
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# In terms of the cost of rent, public transportation station, number of supermarkets nearby, safety, and overall convenience, the Waterloo area in London seems to be a good choice for a temporary stay. While it may have some downsides such as being expensive and crowded with tourists/commuters, it offers great proximity to central London attractions, excellent public transport options, a local feel in certain areas like Lower Marsh St and The Cut, and plenty of amenities within walking distance or a short bus ride away. Overall, for a 3-month stay, the Waterloo area appears to be a winner.
